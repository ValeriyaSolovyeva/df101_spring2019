# %%
import random

students = {}

class Student:
  def __init__ (self, username, id, rating=0, homework=0, test=0, project=0, exam=0 ): #почему id подсвечено? как его обозначить? #нужен ли email и зачем?
    self.username = username
    self.id = ''
    self.rating = rating
    self.homework = homework_grade #нужно ли задавать диапазон численных значений (по 5-ти балльной шкале оценивания)? нужна ли формула среднего арифметического за все д/з?
    self.test = test_grade
    self.project = project_grade
    self.exam = exam_grade
    
  def calc_rating (self):
    self.rating = self.homework*0,1 + self.test*0,2 + self.project*0,3 + self.exam*0,4
   
  def change_rating (self, new_homework, new_test, new_project, new_exam):
    self.homework = new_homework
    self.test = new_test
    self.project = new_project
    self.exam = new_exam
    self.rating = new_homework*0,1 + new_test*0,2 + new_project*0,3 + new_exam*0,4
    
  def generate_id (self):
    self.id = '12345' + str(random.randint (1, 1000))  #зачем нужны числа '12345'?
    
  def add (self):
    students [self.id] = [self.username, self.rating]
    print (self.username + "is added")
    
  def update (user_id): #Где до этого момента было прописано user_id чтобы его апдейтить?
    pass
  
  def menu ():
    while True:
      item = input ("Enter: \n 0 - add new user \n 1 - all users info \n 2 - one user info \n 3 - update existing user's rating \n 4 - delete user ")
      if item == '0':
        user_info = input ("Input: USERNAME HOMEWORK TEST PROJECT EXAM").split()
        username = user_info [0]  #почему нумерация начинается с нуля?
        homework = user_info [1]
        test = user_info [2]
        project = user_info [3]
        exam = user_info [4]
        new_user = Student(username)
        new_user.calc_rating(rating) #что написать в скобках? как сюда поместить формулу расчета рэйтинга?
        new_user.generate_id()
        new_user.add()
        
      elif item == '1': 
        for k, v in student.items():
          print (k, v)
        
      elif item == '2':
        #не знаю, как запросить про одного пользователя
        
      elif item == '3':
        user_id = input ("Enter user's ID to update: ")
        update(user_id)
        
      elif item == '4':
        #как удалить пользователя? __del__?
        
          
menu() #какой параметр задавать в скобках для вызова функции?

# %%
#ПРИМЕР КОДА

import random

students = {}

class Student:
  def __unit__ (self, username):
    self.username = username
    self.rating = 0
    self.id = ''
   
  def set_rating (self, new_rating):
    self.rating = new_rating * 1
    
  def generate_id (self):
    self.id = '12345' + str(random.randint (1, 1000))
    
  def add (self):
    students [self.id] = [self.username, self.rating]
    print (self.username + "is added")
    
  def update (user_id):
    pass
  
  def menu ():
    while True:
      item = input ("Enter: \n 0 - exit \n 1 - add new user \n 2 - update existing user's rating \n 3 - print everything ")
      if item == '0':
        break
        
      elif item == '1':
        user_info = input ("Input: USERNAME RATING").split()
        username = user_info [0]
        rating = user_info [1]
        new_user = Student(username)
        new_user.set_rating(rating)
        new_user.generate_id()
        new_user.add()
        
      elif item == '2':
        user_id = input ("Enter user's ID to update: ")
        update(user_id)
        
      elif item == '3':
        for k, v in student.items():
          print (k, v)
          
menu()
